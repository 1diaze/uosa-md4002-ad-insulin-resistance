# %% [markdown]
# # IR Metrics - Formulas & Units

# %% [markdown]
# ## METS-IR

# %%
# Formula: (ln((2 × Fasting plasma glucose) + Triglyceride concentration) × BMI) / (ln(High-density lipoprotein cholesterol))

# %%
# Units: mg/dL for Fasting Glucose, mg/dL for Triglyceride concentration, kg/m^2 for BMI, mg/dL for HDL-C

# %%
# Source: https://pubmed.ncbi.nlm.nih.gov/29535168/ [ORIGINAL PAPER], https://www.mdcalc.com/calc/10181/metabolic-score-insulin-resistance-mets-ir [CALCULATOR]

# %% [markdown]
# ## Triglyceride-Glucose Index (Tyg)

# %%
# Formula: Ln [Fasting triglycerides) × Fasting plasma glucose)]/2

# %%
# Units: mg/dL for Fasting triglycerides, mg/dL for Fasting glucose

# %%
# Source: https://journals.sagepub.com/doi/epdf/10.1089/met.2008.0034 [ORIGINAL PAPER], https://link.springer.com/article/10.1007/s00431-020-03644-1?utm_source=getftr&utm_medium=getftr&utm_campaign=getftr_pilot&getft_integrator=sciencedirect_contenthosting[CORRECTED FORMULA]

# %% [markdown]
# ## Triglyceride Glucose-Body Mass Index (Tyg-BMI)

# %%
# Formula: TyG index * BMI = {Ln [Fasting triglycerides) × Fasting plasma glucose)]/2} * BMI

# %%
# Units: mg/dL for Fasting triglycerides, mg/dL for Fasting glucose, kg/m^2 for BMI

# %%
# Source: https://pubmed.ncbi.nlm.nih.gov/26930652/

# %% [markdown]
# ## Triglyceride-HDL Ratio

# %%
# Formula: Triglycerides/HDL-C

# %%
# Units: mg/dl for Triglycerides, mg/dL for HDL cholesterol

# %%
# Source: https://www.ajconline.org/article/S0002-9149(05)00741-1/fulltext (note: this includes an investigation into using just HDLs or triglycerides to measure insulin resistance as well)

# %% [markdown]
# ## Other Markers of Insulin Resistance

# %% [markdown]
# #### This paper (https://pmc.ncbi.nlm.nih.gov/articles/PMC3083884/#sec7) provides a list of notable biomarkers associated with insulin resistance (e.g. CRP, Insulin growth factor binding protein-1, Adiponectin, ferritin, etc...). Perhaps could evaluate their association with AD too.
