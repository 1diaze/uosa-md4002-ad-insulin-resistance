# %%
suppressPackageStartupMessages({
    library(dplyr)
    library(tidyr)
    library(tibble)
    library(ggplot2)
    library(performance)
    library(lme4)
    library(tidyverse)
    library(lmerTest)
    library(broom.mixed)
    library(ggeffects)
    library(emmeans)
    library(patchwork)
    library(cowplot)
    library(modelsummary)
    library(datawizard)
    library(see)
})

# %%
# Reading in DATA
tbl1 <- read.csv("063_Phase_II_Cohort")
tbl1 <- tbl1 |>
    rename(VISCODE = VISCODE.x)

# %%
tbl2 <- tbl1 |>
    subset(VISCODE == "bl")
nrow(tbl2) # 296 participants

# %%
# Average age of participants
mean(tbl2$AGE)
sd(tbl2$AGE)

# %%
# Male vs Female
table(tbl2$PTGENDER)

# %%
129/296
167/296

# %%
# Education
mean(tbl2$PTEDUCAT)
sd(tbl2$PTEDUCAT)

# %%
# APOE E4
table(tbl2$APOE4)

# %%
148/296
107/296
41/296

# %%
# Baseline Diagnosis 
table(tbl2$DIAGNOSIS_bl)

# %%
75/296
175/296
46/296

# %%
# Hypertension
table(tbl2$HYPERTENSION)

# %%
183/296
113/296

# %%
# Diabetes
table(tbl2$DIABETES)

# %%
285/296
11/296

# %%
# Smoking
table(tbl2$SMOKING)

# %%
171/296
125/296

# %%
# CVD
table(tbl2$CVD)

# %%
92/296
204/296

# %%
# BMI
mean(tbl2$BMI)
sd(tbl2$BMI)

# %%
# MMSE
mean(tbl2$MMSE)
sd(tbl2$MMSE)

# %%
# Glucose
mean(tbl2$GLUCOSE)
sd(tbl2$GLUCOSE)

# %%
# Triglycerides
mean(tbl2$TOTAL_TG)
sd(tbl2$TOTAL_TG)
